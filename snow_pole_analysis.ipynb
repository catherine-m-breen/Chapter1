# %%
#from tokenize import PlainToken
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
from PIL import Image

# %%
CUB_L_02 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-L-02.csv')
BUNKHOUSE_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_BUNKHOUSE-01.csv')
CEDAR_H_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CEDAR-H-01.csv')
CEDAR_L_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CEDAR-L-01.csv')
CEDAR_M_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CEDAR-M-01.csv')
CUB_H_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-H-01.csv')
CUB_H_02 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-H-02.csv')
CUB_L_02 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-L-02.csv')
CUB_M_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-M-01.csv')
CUB_M_02 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-M-02.csv')
CUB_U_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_CUB-U-01.csv')
TWISP_R_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_TWISP-R-01.csv')
TWISP_U_01 = pd.read_csv('/Users/catherinebreen/Documents/Chapter 1/BenStakes/timeseries_TWISP-U-01.csv')

data = [CEDAR_H_01, CEDAR_L_01,CEDAR_M_01, BUNKHOUSE_01, CUB_L_02, CUB_H_01, CUB_H_02, CUB_M_01, CUB_M_02, CUB_U_01, TWISP_R_01, TWISP_U_01]

# %%
CEDAR_H_01
# Out:
#          camera            Time      filename    x1   y1    x2   y2  \
# 0    CEDAR-H-01  11/21/21 12:00  IMG_0002.JPG  1108  210  1144  822
# 1    CEDAR-H-01  11/22/21 12:00  IMG_0026.JPG  1110  220  1150  828
# 2    CEDAR-H-01  11/23/21 12:00  IMG_0050.JPG  1110  220  1146  826
# 3    CEDAR-H-01  11/24/21 12:00  IMG_0074.JPG  1112  218  1144  828
# 4    CEDAR-H-01  11/25/21 12:00  IMG_0098.JPG  1104  222  1142  812
# ..          ...             ...           ...   ...  ...   ...  ...
# 161  CEDAR-H-01    5/1/22 12:00  IMG_3866.JPG  1110  226  1156  854
# 162  CEDAR-H-01    5/2/22 12:00  IMG_3890.JPG  1112  228  1152  850
# 163  CEDAR-H-01    5/3/22 12:00  IMG_3914.JPG  1110  234  1156  852
# 164  CEDAR-H-01    5/4/22 12:00  IMG_3938.JPG  1106  236  1156  854
# 165  CEDAR-H-01    5/5/22 12:00  IMG_3962.JPG  1106  232  1156  854
#
#      length (pixels)  conversion  length (cm) comment
# 0                613         0.4          0.0     NaN
# ...

# %%
#mismatch['index'][0]
fig, axs = plt.subplots(4, 3, figsize=(24, 24))
rows = 4
cols = 3
idx = 0
for row in range(rows):
    for col in range(cols):
        axs[row, col].plot(data[idx]['Time'], data[idx]['length (cm)'])
        axs[row, col].set_ylim(-5, 300)
        axs[row, col].set_xticks([1,len(data[idx])/2, len(data[idx])-1]) 
        axs[row,col].title.set_text(str(data[idx]['camera'][0])) ## camera ID
        idx += 1

# %%
densityERA = pd.read_csv('/Users/catherinebreen/Documents/Chapter 3/data/ERAresults_snowDensity.csv')

# %%
temperatureERA = pd.read_csv('/Users/catherinebreen/Documents/Chapter 3/data/ERAresults_temperature_2017-20.csv')

# %%
len(temperatureERA)
# Out:
# 29610336

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['January', ' February', 'March', 'April']
y1 = [-6.8, -6.8, -3.3, 0.8]
y2 = [-1.8, -0.9, 3.5, 9.1]

# %%
fig, ax = plt.subplots()

twin1 = ax.twinx()
p2, = twin1.plot(x, [2.0, 1.9, 1.4,0.4], "r-", label="snow depth (m)")
twin1.set_ylim(-3,3)
twin1.set_ylabel('snow depth (m)')
twin1.yaxis.label.set_color(p2.get_color())

ax.fill_between(x, y1, y2)
ax.set_ylim(-10, 10)
ax.axhline(y=0.0, color='black', linestyle='-')
ax.set_ylabel('temperature (Celsius)')

for i, txt in enumerate(y1):
    ax.annotate(y1[i], (x[i], y1[i]))
    ax.annotate(y2[i], (x[i], y2[i]))

# %%
x = ['12AM', '3', '6',  '9',  '12PM', '14',  '17', '20', '_12AM']
y1 = [-6.8, -9, -6, -3, 2, 3, -2, -5, -7]

fig, ax = plt.subplots()

twin1 = ax.twinx()
p2, = twin1.plot(x, [4.9, 5.0, 6.6, 7, 4.0, 3.0, 2.0, 4.0, 4.5], "r-", label="snow hardness (N)")
twin1.set_ylim(-9,9)
twin1.set_ylabel('snow hardness (N)')
twin1.yaxis.label.set_color(p2.get_color())

p1, = ax.plot(x, y1, "white")
ax.set_ylim(-9, 9)
ax.axhline(y=0.0, color='white', linestyle='-')
ax.set_ylabel('temperature (Celsius)')
ax.yaxis.label.set_color(p1.get_color())
